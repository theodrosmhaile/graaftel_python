# %%
import graaftel as gt
import numpy as np
import pandas as pd
import math
import random

# %% [markdown]
# ### Train a new model

# %%
m = gt.Model() # make model object

# add in data file with 3 columns: 
#  student Id | Question Id | Score 
# Note that column headers should not be included

m.init_model(data='test_data/small_dataset_for_testing.csv', nEpochs=1000, nSkills=3) ## at least about a 1000 epochs is safe 

m.get_ratings()

## can save model here if needed. 
#m.save(file_name='test_data_model_4skills')

# %%
### to see a small graph of the trained data(library networkx is required for plotting to work)
gt.make_nodes(m, graph=True)

# %%
gt.make_js_nodes(m)
# Out:
# {'edges': [{'data': {'source': '001', 'target': '011'}},
#   {'data': {'source': '001', 'target': '101'}},
#   {'data': {'source': '000', 'target': '001'}},
#   {'data': {'source': '000', 'target': '100'}},
#   {'data': {'source': '000', 'target': '010'}},
#   {'data': {'source': '100', 'target': '110'}},
#   {'data': {'source': '100', 'target': '101'}},
#   {'data': {'source': '110', 'target': '111'}},
#   {'data': {'source': '010', 'target': '110'}},
#   {'data': {'source': '010', 'target': '011'}},
#   {'data': {'source': '011', 'target': '111'}},
#   {'data': {'source': '101', 'target': '111'}}]}

# %% [markdown]
# ### Run an individual student

# %%
#set student mode to True
m.studentMode = True
m.alpha = 0.08
## If a model is being imported/loaded studentMode will be set at import using m.load_model()

# %%
# if the student does not exist:
m.new_student(name='Teddy')
print('New student skills:', m.students['Teddy'].skills)
# Out:
# New student skills: [0.15796151606083872, 0.16577083825571376, 0.17445007511823912]

# %%
# update student score
m.update_student_rating(name='Teddy', item='2', score=1)
print('Updated student skills:', m.students['Teddy'].skills)
# Out:
# Updated student skills: [0.3390920142517973, 0.3063053804161482, 0.25496550478947433]
